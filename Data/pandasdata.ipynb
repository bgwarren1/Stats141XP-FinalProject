# %%
import pandas as pd

data = pd.read_csv('Copy of Community-engaged Student Experiences, w26 (Responses) - Form Responses 1.csv')

df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (45, 44)

# %%
df.columns[29:]
# Out:
# Index(['I feel ignored or dismissed by my project team.',
#        'I feel that the community partners treat our team as true collaborators.',
#        'The community partners’ knowledge and experience help our team understand the issue(s) we're trying to address.',
#        'We don’t interact enough with community partners to use their input.',
#        'The community partners’ input meaningfully shapes the project’s approach or recommendations.',
# ...

# %%
df = df.rename(columns={
    'Are you first generation to attend college?': 'first_gen_college', 
    "Level of mother's education ": 'mother_education_level', 
    "Level of father's education ": 'father_education_level', 
    'Are you a transfer student?': 'transfer_student', 
    'Range of your GPA at UCLA': 'gpa_range', 
    'How many community-engaged (XP) courses have you taken?': 'xp_courses', 
    'What motivated you to take an XP course?': 'xp_motivation',
    'If you are in a major or minor that requires completion of at least one XP course, what motivated you to add this major/minor?' : 'major_minor_motivation',
    'If you were to rate your sense of belonging (feeling included, heard, respected, identifying with the community, etc.) in your community engagement courses compared to other courses you take across campus, how would you rate it?' : 'belonging_rate',
    "I hesitate to speak up in my XP courses because I think my input won't matter." : 'hesitation_to_participate',
    'I feel respected by the other students on my project team.': 'respected_by_group',
    'I feel my perspective is taken seriously.': 'perspective_inclusion',
    'I feel safe making mistakes while working with my project team.' : 'mistake_safety_in_group',
    'When final decisions are made, I feel my input is not taken into account.': 'input_not_considered',
    'I feel comfortable asking questions or requesting help when needed.': 'comfort_asking_questions',
    'I have a meaningful role in shaping the project team’s decisions.': 'meaningful_role',
    "I worry my contributions aren't valuable.": 'non_valuable_contribution',
    'I feel the community-engaged work is a meaningful way to contribute to the community.': 'community_work_valuable',
    'I feel comfortable sharing my ideas.': 'comfortable_sharing_ideas',
    'I feel ignored or dismissed by my project team.': 'feel_ignored',
    'I feel that the community partners treat our team as true collaborators.': 'community_partners_inclusion',
    "The community partners’ knowledge and experience help our team understand the issue(s) we're trying to address.": 'community_partners_understanding',
    'We don’t interact enough with community partners to use their input.': 'lack_of_interaction_with_partners',
    'The community partners’ input meaningfully shapes the project’s approach or recommendations.': 'do_patners_help',
    'Scenario 1.\nAs part of an XP course, teams of two students are required to volunteer in an after-school tutoring program that supports under-represented students in improving math and reading skills. You enjoy the program and have bonded with the students.\nYou learn that the school district is planning to cut funding for the program. You and your teammate are unhappy about this budget cut and briefly discuss whether to react. Your teammate mentions that you both have very heavy academic schedules and decides not to take any action.': 'scenario_1',
    'Explain the reason behind your choice in Scenario 1. Please be concise.': 'scenario_1_reason',
    'Scenario 2. \nAs part of an XP course, you worked with a community organization that serves immigrant families. During the course, you learned a great deal about the challenges these families face and feel strongly that their concerns are not adequately represented in local decision-making.\nLater, you hear that a public meeting is being planned where community issues will be discussed. You consider speaking at the meeting, but you realize that no one from the community has explicitly asked you to speak on their behalf, and you worry about whether it is appropriate to represent their concerns as a student outsider.': 'scenario_2',
    'Explain the reason behind your choice in Scenario 2. Please be concise.': 'scenario_2_reason',
    'Scenario 3.\nThrough an XP course, you helped analyze data collected by a nonprofit organization to evaluate the effectiveness of one of its programs. The results are positive and could be used to support continued funding.\nHowever, you learn that the data were collected under informal circumstances, and while no rules were violated, the organization is unsure whether the data should be shared publicly. You believe the data could help the organization, but you are concerned about ethical use, consent, and potential misinterpretation.': 'scenario_3',
    'Explain the reason behind your choice in Scenario 3. Please be concise.': 'scenario_3_reason',
    'Scenario 4. \nA friend of yours who is a graduating senior at UCLA took courses in Community Engagement & Social Change and worked with external partners affiliated with the Center for Community Engagement.\nAfter an extensive search, your friend receives two job offers with similar compensation, benefits, and long-term career prospects.\nJob A:\nA position focused on internal projects and organizational objectives, involving teamwork and reporting to a manager.\nJob B:\nA position similar to Job A, but also requiring some time to develop and coordinate activities related to the organization’s external partnerships and interactions with local and/or global communities.\nYour friend finds both jobs equally appealing but is not sure which one to take.': 'scenario_4',
    'Explain the reason behind your choice in Scenario 4. Please be concise.': 'scenario_4_reason',
    'Scenario 5.\nIn a community-engaged course, students are assigned to teams to collaborate with an organization that has designed workshops to support recent immigrant families. The organization offers free evening workshops to help immigrant parents better understand the school system their children attend.\nThe main objective of the project is to develop strategies to improve the workshop attendance, which has been inconsistent. One of your team members suggests that the attendance problem could be solved by replacing the in-person evening meetings with Zoom meetings.\nWhat is your advice?': 'scenario_5',
    'Explain the reason behind your choice in Scenario 5. Please be concise.': 'scenario_5_reason' 
    })

# %%
df = df.rename(columns={
    'Timestamp': 'time', 
    'Date that you took the survey': 'survey_date', 
    'What are the last four digits of your University ID number?': 'last_4_digits_uid', 
    'Last name': 'last_name',  
    'Course that you are enrolled in (Please answer in the format: department name and course number [with no space in between]. e.g., "CESC50XP")': 'enrolled_course',  
    'Your major': 'major', 
    'Your minor': 'minor', 
    'Gender identity ': 'gender',  
    'If you prefer to self-describe your gender identity, please do so here.': 'gender_self_described', 
    'Ethnic Background': 'ethnicity',
       
    })

# %%
df.columns
# Out:
# Index(['time', 'survey_date', 'last_4_digits_uid', 'last_name',
#        'enrolled_course', 'major', 'minor', 'gender', 'gender_self_described',
#        'ethnicity', 'first_gen_college', 'mother_education_level',
#        'father_education_level', 'transfer_student', 'gpa_range', 'xp_courses',
#        'xp_motivation', 'major_minor_motivation', 'belonging_rate',
#        'hesitation_to_participate', 'respected_by_group',
#        'perspective_inclusion', 'mistake_safety_in_group',
#        'input_not_considered', 'comfort_asking_questions', 'meaningful_role',
#        'non_valuable_contribution', 'community_work_valuable',
#        'comfortable_sharing_ideas', 'feel_ignored',
#        'community_partners_inclusion', 'community_partners_understanding',
#        'lack_of_interaction_with_partners', 'do_patners_help', 'scenario_1',
#        'scenario_1_reason', 'scenario_2', 'scenario_2_reason', 'scenario_3',
# ...

# %%
# ordered likert mapping
likert_map = {
    'Hardly ever': 1,
    'Occasionally': 2,
    'Sometimes': 3,
    'Often': 4,
    'Very often': 5
}

# each likert column
likert_cols = [
    'hesitation_to_participate',
    'respected_by_group',
    'perspective_inclusion',
    'mistake_safety_in_group',
    'input_not_considered',
    'comfort_asking_questions',
    'meaningful_role',
    'non_valuable_contribution',
    'community_work_valuable',
    'comfortable_sharing_ideas',
    'feel_ignored',
    'community_partners_inclusion',
    'community_partners_understanding',
    'lack_of_interaction_with_partners',
    'do_patners_help'
]

# map to each colum
df[likert_cols] = df[likert_cols].apply(lambda col: col.map(likert_map))

# %%
df[likert_cols].head()
# Out:
#    hesitation_to_participate  respected_by_group  perspective_inclusion  \
# 0                        4.0                 5.0                    NaN
# 1                        1.0                 4.0                    4.0
# 2                        1.0                 5.0                    5.0
# 3                        1.0                 5.0                    4.0
# 4                        2.0                 5.0                    5.0
#
#    mistake_safety_in_group  input_not_considered  comfort_asking_questions  \
# 0                      NaN                   NaN                         5
# 1                      3.0                   1.0                         5
# 2                      5.0                   1.0                         5
# 3                      4.0                   1.0                         5
# 4                      3.0                   1.0                         5
#
#    meaningful_role  non_valuable_contribution  community_work_valuable  \
# ...
